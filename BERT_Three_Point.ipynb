# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/"Colab Notebooks"/561_Final_Project
# Out:
# /content/drive/MyDrive/Colab Notebooks/561_Final_Project

# %%
# !pip install vaderSentiment
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score
import pickle, argparse, os, sys
from collections import Counter
from tqdm import tqdm
import numpy as np
import pandas as pd
import random
import pickle
import nltk
import math
import re

import torch.functional as F
from torch import optim
import torch.nn as nn
import torch

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# Requirement already satisfied: vaderSentiment in /usr/local/lib/python3.7/dist-packages (3.3.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from vaderSentiment) (2.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (3.0.4)
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# !pip install transformers
import torch
from tqdm.notebook import tqdm
from transformers import BertTokenizer
from torch.utils.data import TensorDataset
from transformers import BertForSequenceClassification
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler
from transformers import AdamW, get_linear_schedule_with_warmup
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.13.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers) (0.0.46)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.62.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.8.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.2.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.10.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.6.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)

# %% [markdown]
# ### Prepare data: split into three sets, replace unfrequent words with UNKA token, and remove stopwords

# %% [markdown]
# Manually checked the quality of the lables and decided to remove rows that have confidence less than 0.4. The removed ones accounted for 1.6 percent of the original data.

# %%
def read_airline_data(data_path = None):
    '''
        read csv data and filter rows with confidence level of the sentiment label lower than 0.4
        
        parms: data path str
        
        return: pandas dataframe
    '''
    #vader sentiment scorer
    analyzer = SentimentIntensityAnalyzer()
    data = pd.read_csv(data_path)
    data = data[["airline_sentiment", "airline_sentiment_confidence", "airline", "text"]]
    data = data[data["airline_sentiment_confidence"] > .4]
    data = data.reset_index(drop = True)
    data["vader_sentiment"] = data["text"].apply(lambda x: analyzer.polarity_scores(x)["compound"])
    return data

# %%
def split_data(data):
    '''
        Split data into three parts
        
        params: pandas dataframe
        return: three pandas dataframe and save as pickle files
    '''
    # split data into training_validation(0.8), validation(0.1), and testing sets(0.1)
    train_valid, test = train_test_split(data, test_size=0.1, random_state=42, shuffle=True, \
                                         stratify=data["airline_sentiment"])
    train, validation = train_test_split(train_valid, test_size=0.1, random_state=42, shuffle=True, \
                                         stratify=train_valid["airline_sentiment"])
    train_pkl = open("train.pkl", "wb")
    pickle.dump(train, train_pkl)
    train_pkl.close()
    
    validation_pkl = open("validation.pkl", "wb")
    pickle.dump(validation, validation_pkl)
    validation_pkl.close()
    
    test_pkl = open("test.pkl", "wb")
    pickle.dump(test, test_pkl)
    test_pkl.close()

    return

# %%
def prepare_data(data):
    '''
        create token list for the tweets and create a vocabulary dictionary 
        to replace unfrequent words with UNKA
        
        Also create a token_to_idx dictionary include special token <PAD>
        
        Besides, convert sentiment label into integers and create one hot vectors

        param: pandas dataframe
        return: #token_to_idx, dict
                
    '''
    
    # remove stopwords
    # tokenize tweets
    # create vocab list for checking frequency
    stop_words = set(stopwords.words('english'))
    filtered_text_list = []
    vocab_list = []
    for tweet in tqdm(data["text"]):
        tweet = re.sub("\@[A-Za-z]+", "", tweet)
        tweet = re.sub("http\S+", "", tweet)
        tweet = re.sub("[!.,@#$%^&*]", "", tweet)
        tokens = word_tokenize(tweet)
        filtered_text = [w for w in tokens if not w in stop_words] 
        filtered_text_list.append(filtered_text)
        vocab_list += filtered_text
    data["filtered_text"] = filtered_text_list
    
    # replace unfrequent words with "UNKA"
    vocab_dict = Counter(vocab_list)
    token_to_replace = {k: v for k, v in vocab_dict.items() if v < 3}
    
    for tweet in tqdm(data["filtered_text"]):
        for token_idx in range(len(tweet)):
            if tweet[token_idx] in token_to_replace:
                tweet[token_idx] = "UNKA"

    # create index for sentiment labels
    sentiment_to_idx = {"neutral":0, "negative":1, "positive":2}
    data["label_idx"] = data["airline_sentiment"].apply(lambda x: sentiment_to_idx[x])

    # convert tweet from list into str for BERT
    data["filtered_text"] = data["filtered_text"].apply(lambda x: " ".join(x))
        
    return

# %% [markdown]
# Tokenize data and prepare dataset for training

# %%
def prepare_dataset():
    tokenizer = BertTokenizer.from_pretrained('bert-base-uncased', 
                                            do_lower_case=True)
    train_file = open("train.pkl", "rb")
    train_data = pickle.load(train_file)
    train_file.close()

    valid_file = open("validation.pkl", "rb")
    valid_data = pickle.load(valid_file)
    valid_file.close()

    test_file = open("test.pkl", "rb")
    test_data = pickle.load(test_file)
    test_file.close()

    # Data cleaning before training and testing
    prepare_data(train_data)
    prepare_data(valid_data)
    prepare_data(test_data)
                                            
    encoded_data_train = tokenizer.batch_encode_plus(
        train_data.filtered_text.values, 
        add_special_tokens=True, 
        return_attention_mask=True, 
        padding=True, 
        max_length=20, 
        return_tensors='pt'
    )

    encoded_data_val = tokenizer.batch_encode_plus(
        valid_data.filtered_text.values, 
        add_special_tokens=True, 
        return_attention_mask=True, 
        padding=True, 
        max_length=20, 
        return_tensors='pt'
    )

    encoded_data_test = tokenizer.batch_encode_plus(
        test_data.filtered_text.values, 
        add_special_tokens=True, 
        return_attention_mask=True, 
        padding=True, 
        max_length=20, 
        return_tensors='pt'
    )

    input_ids_train = encoded_data_train['input_ids']
    input_ids_train[:, -1] = torch.tensor(train_data["vader_sentiment"].tolist())
    attention_masks_train = encoded_data_train['attention_mask']
    labels_train = torch.tensor(train_data.label_idx.values)

    input_ids_val = encoded_data_val['input_ids']
    input_ids_val[:, -1] = torch.tensor(valid_data["vader_sentiment"].tolist())
    attention_masks_val = encoded_data_val['attention_mask']
    labels_val = torch.tensor(valid_data.label_idx.values)

    input_ids_test = encoded_data_test['input_ids']
    input_ids_test[:, -1] = torch.tensor(test_data["vader_sentiment"].tolist())
    attention_masks_test = encoded_data_test['attention_mask']
    labels_test = torch.tensor(test_data.label_idx.values)

    dataset_train = TensorDataset(input_ids_train, attention_masks_train, labels_train)
    dataset_val = TensorDataset(input_ids_val, attention_masks_val, labels_val)
    dataset_test = TensorDataset(input_ids_test, attention_masks_test, labels_test)

    return dataset_train, dataset_val, dataset_test
# Out:
#   0%|          | 0/11666 [00:00<?, ?it/s]
#   0%|          | 0/11666 [00:00<?, ?it/s]
#   0%|          | 0/1297 [00:00<?, ?it/s]
#   0%|          | 0/1297 [00:00<?, ?it/s]
#   0%|          | 0/1441 [00:00<?, ?it/s]
#   0%|          | 0/1441 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2238: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "

# %% [markdown]
# BERT pre-trained model

# %%
def train(dataset_train, dataset_val):


    epochs = 5
    seed_val = 17
    batch_size = 10
    random.seed(seed_val)
    np.random.seed(seed_val)
    torch.manual_seed(seed_val)
    torch.cuda.manual_seed_all(seed_val)
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    sentiment_to_idx = {"neutral":0, "negative":1, "positive":2}
    model = BertForSequenceClassification.from_pretrained("bert-base-uncased",
                                                        num_labels=len(sentiment_to_idx),
                                                        output_attentions=False,
                                                        output_hidden_states=False)
    
    
    dataloader_train = DataLoader(dataset_train, 
                                sampler=RandomSampler(dataset_train), 
                                batch_size=batch_size)
    dataloader_validation = DataLoader(dataset_val, 
                                   sampler=SequentialSampler(dataset_val), 
                                   batch_size=batch_size)

    optimizer = AdamW(model.parameters(),
                  lr=2e-5, 
                  eps=1e-8)    
    scheduler = get_linear_schedule_with_warmup(optimizer, 
                                            num_warmup_steps=0,
                                            num_training_steps=len(dataloader_train)*epochs)
                                        
    model.to(device)

    # train starts
    for epoch in tqdm(range(1, epochs+1)):
        
        model.train()
        loss_train_total = 0

        progress_bar = tqdm(dataloader_train, desc='Epoch {:1d}'.format(epoch), leave=False, disable=False)
        for batch in progress_bar:

            model.zero_grad()
            
            batch = tuple(b.to(device) for b in batch)
            
            inputs = {'input_ids':      batch[0],
                    'attention_mask': batch[1],
                    'labels':         batch[2],
                    }       
            print("iput ids:", batch[0])
            print("labels", batch[2])

            outputs = model(**inputs)
            print("outputs", outputs)
            print("outputs[0]", outputs[0])
            loss = outputs[0]
            loss_train_total += loss.item()
            loss.backward()

            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

            # Performs a single optimization step (parameter update).
            optimizer.step()
            # You call scheduler.step() every batch, right after optimizer.step(), to update the learning rate.
            scheduler.step()
            
            progress_bar.set_postfix({'training_loss': '{:.3f}'.format(loss.item()/len(batch))})
            
            
        torch.save(model.state_dict(), f'second_finetuned_BERT_epoch_{epoch}.model')
            
        tqdm.write(f'\nEpoch {epoch}')
        
        loss_train_avg = loss_train_total/len(dataloader_train)            
        tqdm.write(f'Training loss: {loss_train_avg}')
        
        val_loss, predictions, true_vals = evaluate(dataloader_validation)
        _, predicted = torch.max(torch.tensor(predictions), 1)
        f1_score_pos, f1_score_neg, f1_score, accuracy_table = calculate_f1(predicted, true_vals)
        tqdm.write(f'Validation loss: {val_loss}')
        tqdm.write(f'F1 Score (Weighted): {f1_score}')
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
def evaluate(dataloader_val):
    
    sentiment_to_idx = {"neutral":0, "negative":1, "positive":2}
    model = BertForSequenceClassification.from_pretrained("bert-base-uncased",
                                                        num_labels=len(sentiment_to_idx),
                                                        output_attentions=False,
                                                        output_hidden_states=False)

    model.eval()
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model.to(device)

    loss_val_total = 0
    predictions, true_vals = [], []
    
    for batch in dataloader_val:
        
        batch = tuple(b.to(device) for b in batch)
        
        inputs = {'input_ids':      batch[0],
                  'attention_mask': batch[1],
                  'labels':         batch[2],
                 }

        with torch.no_grad():        
            outputs = model(**inputs)
            
        loss = outputs[0]
        print("During training one batch, the loss of the output is:", loss)
        print("Loss.item:", loss.item())
        logits = outputs[1]
        print("During training one batch, the logits of the output is:", logits)
        loss_val_total += loss.item()

        logits = logits.detach().cpu().numpy()
        label_ids = inputs['labels'].cpu().numpy()
        predictions.append(logits)
        true_vals.append(label_ids)
    
    loss_val_avg = loss_val_total/len(dataloader_val) 
    
    predictions = np.concatenate(predictions, axis=0)
    true_vals = np.concatenate(true_vals, axis=0)
            
    return loss_val_avg, predictions, true_vals

# %%
def calculate_f1(prediction, ground_truth):
    '''
        calculate the f1 score for positive and
        negative labels and the overall f1 score
        
        params: arrays
        return: three f1 scores
    '''
    accuracy_table = torch.zeros(3,3)

    for pred, truth in zip(prediction, ground_truth):
        if (pred, truth) == (2, 2):
            accuracy_table[0][0] += 1
        elif (pred, truth) == (2, 0):
            accuracy_table[0][1] += 1
        elif (pred, truth) == (2, 1):
            accuracy_table[0][2] += 1
        elif (pred, truth) == (0, 2):
            accuracy_table[1][0] += 1
        elif (pred, truth) == (0, 0):
            accuracy_table[1][1] += 1
        elif (pred, truth) == (0, 1):
            accuracy_table[1][2] += 1
        elif (pred, truth) == (1, 2):
            accuracy_table[2][0] += 1
        elif (pred, truth) == (1, 0):
            accuracy_table[2][1] += 1
        elif (pred, truth) == (1, 1):
            accuracy_table[2][2] += 1


    presition_pos = accuracy_table[0][0] / (accuracy_table[0][0] +  accuracy_table[0][1] + accuracy_table[0][2])
    recall_pos = accuracy_table[0][0] / (accuracy_table[0][0] +  accuracy_table[1][0] + accuracy_table[2][0])
    presition_neg = accuracy_table[2][2] / (accuracy_table[2][0] +  accuracy_table[2][1] + accuracy_table[2][2])
    recall_neg = accuracy_table[2][2] / (accuracy_table[0][2] +  accuracy_table[1][2] + accuracy_table[2][2])

    f1_score_pos = (2 * presition_pos * recall_pos) / (presition_pos + recall_pos)
    f1_score_neg = (2 * presition_neg * recall_neg) / (presition_neg + recall_neg)
    f1_score = (f1_score_pos + f1_score_neg) / 2

    return f1_score_pos, f1_score_neg, f1_score, accuracy_table

# %% [markdown]
# Evaluate the test set

# %%
def test(model_path = 'second_finetuned_BERT_epoch_5.model'):
    
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    sentiment_to_idx = {"neutral":0, "negative":1, "positive":2}

    model = BertForSequenceClassification.from_pretrained("bert-base-uncased",
                                                        num_labels=len(sentiment_to_idx),
                                                        output_attentions=False,
                                                        output_hidden_states=False)

    model.to(device)
    model.load_state_dict(torch.load(model_path, map_location=torch.device('cpu')))

    batch_size = 10
    dataloader_test = DataLoader(dataset_test, 
                                    sampler=SequentialSampler(dataset_test), 
                                    batch_size=batch_size)
    val_loss, predictions, true_vals = evaluate(dataloader_test)
    _, predicted = torch.max(torch.tensor(predictions), 1)
    f1_score_pos, f1_score_neg, f1_score, accuracy_table = calculate_f1(predicted, true_vals)
    print(f1_score)
    print(f1_score_pos)
    print(f1_score_neg)
# Out:
# During training one batch, the loss of the output is: tensor(1.3755, device='cuda:0')
# Loss.item: 1.3754916191101074
# During training one batch, the logits of the output is: tensor([[ 5.0085, -2.4256, -2.6018],
#         [-1.9738,  5.4768, -3.5031],
#         [-2.0593,  5.5874, -3.4753],
#         [-3.4115,  5.1426, -1.9078],
#         [-0.6394, -1.4386,  1.9912],
#         [-1.9394,  4.8763, -3.2493],
#         [-1.9062, -2.4988,  4.8202],
#         [ 0.9728, -0.0138, -1.2189],
#         [-2.5847,  5.8612, -3.2667],
#         [-1.5838,  4.9368, -3.4926]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.6349, device='cuda:0')
# Loss.item: 0.6349061131477356
# During training one batch, the logits of the output is: tensor([[ 4.7010, -2.7121, -2.3938],
#         [-3.7098,  2.4736,  1.5269],
#         [-2.7467, -0.9309,  4.1108],
#         [-1.9075,  5.3352, -3.3383],
#         [-2.3440, -2.5689,  5.0318],
#         [-1.2589,  3.0836, -2.3523],
#         [-1.7379,  5.4016, -3.7258],
#         [-2.3638,  5.5045, -3.2960],
#         [-2.3658,  5.6183, -3.2948],
#         [-1.9273,  5.0555, -3.2150]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.0045, device='cuda:0')
# Loss.item: 0.004523974843323231
# During training one batch, the logits of the output is: tensor([[-2.4689e+00,  5.6701e+00, -3.2489e+00],
#         [ 4.8236e+00, -2.7927e+00, -2.3402e+00],
#         [-2.1691e+00, -2.5087e+00,  4.9813e+00],
#         [-1.5172e-01, -3.7490e+00,  4.3218e+00],
#         [-2.6090e+00,  5.8088e+00, -3.2096e+00],
#         [-2.1841e+00,  5.4025e+00, -3.3252e+00],
#         [-1.9136e+00,  4.1609e+00, -2.5036e+00],
#         [-1.8106e+00,  5.2864e+00, -3.5344e+00],
#         [ 2.9456e-03,  3.7202e+00, -3.6116e+00],
#         [-2.6612e+00,  5.7761e+00, -3.1466e+00]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(1.6355, device='cuda:0')
# Loss.item: 1.6354726552963257
# During training one batch, the logits of the output is: tensor([[-2.1879,  5.6906, -3.5241],
#         [-2.4435,  5.8390, -3.4015],
#         [ 4.1260, -4.0580, -0.1761],
#         [-1.9272,  4.7269, -2.7401],
#         [ 3.0424, -3.9494,  1.2606],
#         [-0.0334,  3.7665, -3.2984],
#         [-2.1674,  5.5949, -3.4488],
#         [-2.1582,  5.6978, -3.5459],
#         [-1.6568, -1.1798,  3.6713],
#         [-2.5378,  5.6938, -3.2342]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.7379, device='cuda:0')
# Loss.item: 0.7378960251808167
# During training one batch, the logits of the output is: tensor([[-2.1940,  5.4680, -3.3703],
#         [-2.3240, -2.3256,  4.9689],
#         [ 2.9028, -1.9989, -0.9831],
#         [-2.5228,  5.5397, -3.1462],
#         [ 1.1569,  1.7892, -2.7372],
#         [-2.5846,  5.8607, -3.2775],
#         [-2.1266,  5.4267, -3.4198],
#         [-2.0268,  4.6709, -2.6639],
#         [-2.1267, -2.3453,  4.7798],
#         [-1.3118,  4.2162, -3.2903]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(1.7516, device='cuda:0')
# Loss.item: 1.7516200542449951
# During training one batch, the logits of the output is: tensor([[ 2.3048, -4.3183,  2.4689],
#         [-2.9090,  5.3287, -2.5809],
#         [-1.6457, -3.0079,  4.8502],
#         [-0.0702, -3.8557,  4.1422],
#         [-2.3204,  5.6668, -3.4180],
#         [ 3.8417, -2.4575, -1.7286],
#         [ 3.5728, -2.8412, -0.3678],
#         [-2.2932,  5.4576, -3.2907],
#         [ 1.5185, -0.6445, -1.8906],
#         [-1.4744,  4.6597, -3.3146]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(1.8623, device='cuda:0')
# Loss.item: 1.8622938394546509
# During training one batch, the logits of the output is: tensor([[ 4.8878, -2.5628, -2.4716],
#         [-1.7765,  3.8856, -2.3004],
#         [-2.2085,  5.5586, -3.4166],
#         [-2.4645,  5.5388, -3.1713],
#         [ 4.9895, -3.4713, -1.4429],
#         [-2.4129,  5.8633, -3.4029],
#         [-2.2853, -2.5550,  4.9982],
#         [-2.2771,  5.5340, -3.3504],
#         [-0.7411,  3.6564, -3.1381],
#         [ 5.0086, -2.6933, -2.4809]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.7905, device='cuda:0')
# Loss.item: 0.7904627919197083
# During training one batch, the logits of the output is: tensor([[ 2.8690,  1.7544, -4.4440],
#         [ 4.8453, -1.9586, -2.5621],
#         [-2.4953,  5.8885, -3.3622],
#         [ 2.1468,  2.3399, -4.4908],
#         [-2.0617,  5.3386, -3.3900],
#         [-2.3243,  3.6988, -1.4831],
#         [-2.6284, -2.2485,  4.9729],
#         [ 5.1490, -2.8149, -2.2520],
#         [-1.1068,  3.9874, -3.1966],
#         [-2.6478,  4.8264, -1.9633]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.7480, device='cuda:0')
# Loss.item: 0.7480039000511169
# During training one batch, the logits of the output is: tensor([[ 0.5612,  3.8429, -4.1903],
#         [-2.1932, -2.5410,  4.9481],
#         [-2.3831,  5.7318, -3.3705],
#         [ 4.5040, -1.9216, -3.0105],
#         [-2.3919,  5.7944, -3.4089],
#         [-2.5351,  5.7772, -3.3024],
#         [ 1.9136,  2.4436, -4.0283],
#         [-2.3523,  5.6068, -3.3228],
#         [-1.7452,  5.3367, -3.6049],
#         [ 3.2880, -1.6609, -1.2878]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(3.3382, device='cuda:0')
# Loss.item: 3.3381829261779785
# During training one batch, the logits of the output is: tensor([[ 0.1087,  3.0169, -3.4531],
#         [ 1.7150, -3.9612,  2.5457],
#         [ 2.8073, -2.1439, -1.7200],
#         [-2.5422, -2.1806,  4.8557],
#         [ 0.2959, -4.0303,  3.7240],
#         [ 0.9121,  2.4524, -3.2743],
#         [-2.1630,  5.0919, -3.0165],
#         [-2.7948,  5.6764, -2.9862],
#         [ 5.0864, -2.6480, -2.5083],
#         [-2.1989,  5.4593, -3.3602]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.4490, device='cuda:0')
# Loss.item: 0.4489794373512268
# During training one batch, the logits of the output is: tensor([[-2.3185,  5.6035, -3.3814],
#         [-2.2066,  5.6653, -3.5281],
#         [-2.4067,  2.1961,  0.8934],
#         [-1.7671, -3.0338,  4.9759],
#         [-2.3965,  5.5518, -3.3055],
#         [ 0.1170,  4.3284, -4.3082],
#         [-0.6078,  3.9655, -3.6484],
#         [-2.3709,  5.5701, -3.3524],
#         [-2.0923,  5.7358, -3.5897],
#         [-2.1986,  5.6795, -3.4827]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(1.3824, device='cuda:0')
# Loss.item: 1.3823715448379517
# During training one batch, the logits of the output is: tensor([[ 4.7077, -2.6029, -2.4125],
#         [-2.4115,  5.3694, -3.1080],
#         [-2.1784,  5.6813, -3.5059],
#         [-2.3537, -2.5841,  5.0255],
#         [ 4.2608, -0.9238, -3.6296],
#         [-1.6244,  4.7731, -3.1980],
#         [ 3.6784, -2.0343, -2.5661],
#         [ 2.5317, -3.6535,  1.5382],
#         [-2.6623,  5.5660, -3.0062],
#         [-1.9430,  5.1238, -3.3339]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.8853, device='cuda:0')
# Loss.item: 0.8853212594985962
# During training one batch, the logits of the output is: tensor([[ 5.0592, -2.7433, -1.9283],
#         [-1.1798,  4.4202, -3.4706],
#         [-1.2133, -3.0691,  4.7034],
#         [-2.2422,  5.5929, -3.4184],
#         [-2.2555,  5.5872, -3.4530],
#         [-2.5842,  5.6973, -3.1738],
#         [-2.4989, -2.5127,  5.0417],
#         [-3.5313,  2.4264,  1.2400],
#         [-2.0621,  5.3239, -3.2197],
#         [-2.4470,  5.4880, -3.2052]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(1.8227, device='cuda:0')
# Loss.item: 1.822699785232544
# During training one batch, the logits of the output is: tensor([[-2.7637,  5.1760, -2.4653],
#         [-0.6704,  4.0190, -3.2177],
#         [-1.6960, -2.7833,  4.8671],
#         [-2.0191,  5.6160, -3.6144],
#         [-2.8919,  5.2847, -2.4591],
#         [-1.9601,  5.3657, -3.5008],
#         [-2.5132,  5.2638, -2.9569],
#         [ 3.7491, -3.7900, -0.0658],
#         [-1.2146,  5.0672, -3.7845],
#         [-2.6210, -1.8668,  4.7598]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(1.4384, device='cuda:0')
# Loss.item: 1.4383628368377686
# During training one batch, the logits of the output is: tensor([[-2.2511,  4.9754, -2.8292],
#         [-2.4809,  5.8428, -3.3720],
#         [-2.4325,  5.6113, -3.2985],
#         [ 3.7773, -2.2648, -2.3452],
#         [-0.8010, -2.9360,  4.0989],
#         [-2.4942,  5.7594, -3.3221],
#         [-2.2252,  5.2143, -2.9783],
#         [ 3.2960,  1.0911, -4.0085],
#         [-2.0347,  5.5642, -3.6077],
#         [-2.6572,  5.8665, -3.2440]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(1.0983, device='cuda:0')
# Loss.item: 1.0983188152313232
# During training one batch, the logits of the output is: tensor([[ 4.0415, -3.0743, -1.4905],
#         [ 4.9287, -2.3832, -2.7394],
#         [-1.9642, -0.0357,  2.7882],
#         [-2.4860,  5.7030, -3.2302],
#         [-0.7055, -3.3600,  4.4319],
#         [-3.1410,  0.6287,  2.9512],
#         [-2.5105,  5.8301, -3.3333],
#         [ 2.0648,  0.2418, -2.9729],
#         [-2.4000,  5.7740, -3.4073],
#         [-1.5618,  4.9442, -3.4252]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.8777, device='cuda:0')
# Loss.item: 0.8776551485061646
# During training one batch, the logits of the output is: tensor([[ 0.3537,  0.1959, -0.3150],
#         [-2.3005,  4.1247, -1.7789],
#         [ 4.4332, -3.6125, -0.4995],
#         [-2.7611,  5.6937, -2.8125],
#         [-2.3794,  5.8333, -3.3917],
#         [ 4.5455, -2.5132, -2.6177],
#         [-2.2332,  5.1206, -3.0520],
#         [ 1.1095,  1.8754, -3.3363],
#         [ 4.3731, -2.3866, -2.3576],
#         [-3.1722,  5.4568, -2.3138]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(2.2573, device='cuda:0')
# Loss.item: 2.257286310195923
# During training one batch, the logits of the output is: tensor([[-2.1202,  5.5724, -3.3959],
#         [-2.0251,  5.2954, -3.3600],
#         [ 4.0948, -1.9090, -2.8929],
#         [-2.0330,  5.0199, -3.1864],
#         [-1.5706,  5.1262, -3.6530],
#         [-2.5129,  5.7660, -3.2895],
#         [-1.3755,  5.4154, -3.8005],
#         [-2.1780, -2.7595,  5.0323],
#         [-1.3583,  0.3788,  0.7674],
#         [ 4.2029, -1.8007, -3.0706]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(2.0567, device='cuda:0')
# Loss.item: 2.056687831878662
# During training one batch, the logits of the output is: tensor([[-1.6632,  4.7989, -3.1451],
#         [ 4.1407, -2.1258, -2.6123],
#         [-2.5030,  5.5735, -3.2394],
#         [ 4.5793, -2.4553, -2.3823],
#         [-1.7127,  5.2345, -3.5330],
#         [-2.1130, -2.6456,  4.9647],
#         [-2.1381, -2.6974,  4.9832],
#         [ 1.8784, -0.7503, -2.2242],
#         [ 2.6609,  1.9237, -4.3903],
#         [-0.4594,  4.2090, -3.4010]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(1.6561, device='cuda:0')
# Loss.item: 1.6561107635498047
# During training one batch, the logits of the output is: tensor([[-2.0984,  5.3883, -3.3213],
#         [-0.7961, -3.3055,  4.4602],
#         [-2.3073, -2.4815,  4.9892],
#         [-2.4918,  5.8626, -3.3061],
#         [-1.1295,  3.8307, -2.6440],
#         [ 2.1265, -4.0353,  1.2210],
#         [-2.3665, -2.4645,  5.0112],
#         [-2.2915,  4.2772, -2.0644],
#         [ 3.2750,  0.4773, -4.0571],
#         [-2.3491,  5.8065, -3.4110]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(2.1753, device='cuda:0')
# Loss.item: 2.175330400466919
# During training one batch, the logits of the output is: tensor([[-1.8326,  5.1040, -3.3512],
#         [-2.3173,  5.5496, -3.2808],
#         [-2.6663,  5.8091, -3.1863],
#         [ 4.2136, -2.1003, -2.7030],
#         [-2.6765,  5.7341, -3.0361],
#         [-2.0948,  5.5166, -3.5082],
#         [ 3.1843, -2.4714, -0.8556],
#         [-1.9330,  4.3136, -2.6300],
#         [ 5.1750, -3.0165, -2.0147],
#         [-2.3481,  5.8125, -3.4617]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.4261, device='cuda:0')
# Loss.item: 0.42606228590011597
# During training one batch, the logits of the output is: tensor([[-2.4560,  5.4923, -3.1508],
#         [-0.0702, -3.8557,  4.1422],
#         [-2.2804,  5.7105, -3.4860],
#         [ 0.5435,  4.1600, -4.4754],
#         [ 4.3616, -2.4715, -2.3483],
#         [-1.9954,  5.4696, -3.5777],
#         [-2.5011,  5.8040, -3.2942],
#         [-2.3844,  5.8236, -3.4415],
#         [-2.3797, -2.5462,  5.0459],
#         [-2.7605,  5.2582, -2.5578]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(2.8137, device='cuda:0')
# Loss.item: 2.8137152194976807
# During training one batch, the logits of the output is: tensor([[-1.4437, -1.8258,  4.0067],
#         [ 1.6318,  3.0119, -4.4915],
#         [-1.6889, -2.9142,  4.8158],
#         [-2.2532,  5.5093, -3.3585],
#         [ 4.3952, -1.6708, -3.2004],
#         [-2.3821,  5.8952, -3.3944],
#         [-1.5334, -1.2796,  3.2353],
#         [-2.8756,  4.3485, -1.7230],
#         [-2.7145,  5.4878, -2.9298],
#         [ 4.5919, -2.6453, -2.4722]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(2.2472, device='cuda:0')
# Loss.item: 2.247162342071533
# During training one batch, the logits of the output is: tensor([[ 4.5908, -2.4003, -2.7603],
#         [ 4.4940, -1.6231, -3.1346],
#         [-1.9548,  4.7431, -2.9761],
#         [-1.9361,  5.5968, -3.7053],
#         [-2.5655,  5.8518, -3.2935],
#         [-2.1770,  5.3707, -3.3279],
#         [ 2.5397, -2.1822,  0.0950],
#         [-2.7475,  5.6106, -2.9512],
#         [-1.7418, -2.5256,  4.6716],
#         [-2.0824,  5.4276, -3.4734]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(2.6011, device='cuda:0')
# Loss.item: 2.6010992527008057
# During training one batch, the logits of the output is: tensor([[ 4.2167, -1.8378, -3.0690],
#         [ 1.5185, -0.6445, -1.8906],
#         [ 2.6953, -4.0850,  2.0427],
#         [-1.1670, -2.5916,  4.3278],
#         [-2.2422, -2.3571,  4.8616],
#         [ 4.6971, -2.5862, -2.3150],
#         [ 1.5185, -0.6445, -1.8906],
#         [ 0.5974, -1.4484,  1.2817],
#         [ 2.8202, -3.0187,  0.7446],
#         [ 5.0893, -2.7924, -2.3485]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.2825, device='cuda:0')
# Loss.item: 0.2824857234954834
# During training one batch, the logits of the output is: tensor([[ 0.1708,  2.9232, -2.7440],
#         [-2.1718,  5.8504, -3.5723],
#         [-2.3641,  5.6582, -3.3472],
#         [-2.6673,  5.7384, -3.0672],
#         [ 4.7886, -2.4032, -2.6727],
#         [ 4.7629, -2.3852, -2.6987],
#         [-2.4268,  4.7830, -2.4990],
#         [-2.3105,  5.7092, -3.4434],
#         [-2.5752,  5.4750, -3.1110],
#         [-1.8203,  5.1647, -3.3734]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(1.1606, device='cuda:0')
# Loss.item: 1.160649061203003
# During training one batch, the logits of the output is: tensor([[-2.3490,  5.7160, -3.4441],
#         [-2.6296,  5.8323, -3.2029],
#         [ 2.1879, -0.9121, -2.3932],
#         [-2.5173,  5.7180, -3.1936],
#         [-0.2029,  1.2135, -1.0425],
#         [ 0.1453, -3.8529,  4.0788],
#         [-2.2513,  5.5344, -3.2361],
#         [ 2.6372, -3.8347,  0.9972],
#         [-1.7982,  5.1928, -3.2255],
#         [-2.4805,  5.6916, -3.3261]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.6799, device='cuda:0')
# Loss.item: 0.679871141910553
# During training one batch, the logits of the output is: tensor([[-2.2708,  5.7463, -3.4962],
#         [-2.5223,  5.7344, -3.2801],
#         [-2.2523,  5.7267, -3.5316],
#         [ 4.6485, -2.1197, -2.8802],
#         [ 4.1570, -2.7148, -1.9200],
#         [-1.3251,  3.0986, -1.6740],
#         [ 4.5370, -2.0451, -2.9353],
#         [-2.2130,  5.7429, -3.5020],
#         [ 4.9047, -2.5906, -2.5058],
#         [-2.3767,  5.6566, -3.3470]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(2.2822, device='cuda:0')
# Loss.item: 2.282196521759033
# During training one batch, the logits of the output is: tensor([[-0.0702, -3.8557,  4.1422],
#         [ 4.6342, -2.3063, -2.7971],
#         [ 3.4098, -0.6603, -2.8470],
#         [-3.0826,  4.9789, -2.1150],
#         [-2.0915,  5.6756, -3.5225],
#         [ 4.9525, -1.6908, -2.9182],
#         [-2.4422,  5.7936, -3.3863],
#         [ 3.1901,  1.1708, -4.0352],
#         [-2.6728,  5.5090, -2.9917],
#         [-2.3426, -2.1662,  4.8861]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(1.2720, device='cuda:0')
# Loss.item: 1.2719807624816895
# During training one batch, the logits of the output is: tensor([[ 4.7837, -3.4314, -1.1231],
#         [-1.9568,  4.9601, -3.1157],
#         [-0.1870,  4.2269, -4.0522],
#         [-2.5021,  5.7950, -3.2826],
#         [-2.5066,  5.8611, -3.2888],
#         [-2.6677,  5.3958, -2.9061],
#         [-0.1257,  2.7271, -2.5464],
#         [-0.6845,  4.5757, -3.7722],
#         [-2.0749,  5.4733, -3.4743],
#         [ 4.4102, -3.3757, -0.7683]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.9871, device='cuda:0')
# Loss.item: 0.9870601892471313
# During training one batch, the logits of the output is: tensor([[-2.2613,  5.6608, -3.4852],
#         [-1.9305,  4.6418, -2.7780],
#         [ 4.8686, -2.4670, -2.6273],
#         [ 3.5955, -3.8564,  0.4610],
#         [-2.4507,  5.7786, -3.3666],
#         [ 0.6385,  3.0205, -3.8352],
#         [-2.2279,  4.7469, -2.6023],
#         [-2.1427,  5.5259, -3.4626],
#         [-2.3300,  5.7242, -3.4617],
#         [ 4.6462, -1.9490, -3.0973]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.0068, device='cuda:0')
# Loss.item: 0.006768425460904837
# During training one batch, the logits of the output is: tensor([[-0.2467, -3.6365,  4.2007],
#         [-2.3442,  5.4574, -3.1998],
#         [-2.1854,  5.5937, -3.5093],
#         [-2.2769,  5.5262, -3.3629],
#         [-2.4196, -2.5234,  5.0396],
#         [ 4.8404, -2.4569, -2.7180],
#         [ 0.4934, -3.6191,  3.6296],
#         [-2.9028,  4.1243, -1.1549],
#         [-2.1016,  4.9750, -3.0170],
#         [ 4.7993, -2.7126, -2.3338]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.7343, device='cuda:0')
# Loss.item: 0.7342785596847534
# During training one batch, the logits of the output is: tensor([[-2.5679,  5.7207, -3.1413],
#         [ 3.9212, -1.9555, -2.6954],
#         [-2.4881,  5.7664, -3.2920],
#         [-1.7836, -2.8555,  4.9175],
#         [-2.6200,  5.5653, -3.0645],
#         [-1.9579, -2.6687,  4.9166],
#         [-2.2515,  5.7303, -3.4864],
#         [-1.7876,  5.1506, -3.4887],
#         [-1.5504,  4.5655, -3.0000],
#         [-3.3372,  1.8931,  2.0314]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.6465, device='cuda:0')
# Loss.item: 0.6464718580245972
# During training one batch, the logits of the output is: tensor([[ 3.8451, -2.5394, -2.0789],
#         [-2.1125,  5.4025, -3.1079],
#         [-2.0413,  5.6676, -3.6188],
#         [-2.0760,  5.6969, -3.5845],
#         [-2.6938, -2.0633,  4.8819],
#         [-2.3404,  5.5901, -3.2737],
#         [-2.3728,  5.6882, -3.3934],
#         [ 0.4128,  3.0514, -3.5189],
#         [-2.0886,  5.5531, -3.4064],
#         [-2.1083,  5.3914, -3.4250]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(1.8027, device='cuda:0')
# Loss.item: 1.802695631980896
# During training one batch, the logits of the output is: tensor([[-0.6702,  4.2905, -3.6430],
#         [-1.4845,  5.3507, -3.8996],
#         [-2.3901,  5.8877, -3.4409],
#         [-2.2490,  5.5766, -3.4092],
#         [-0.4298,  4.6424, -3.9553],
#         [-3.0566,  4.5737, -1.5182],
#         [ 4.7285, -4.0818, -0.3841],
#         [-2.3862,  5.8099, -3.4194],
#         [-2.5717,  5.9167, -3.2833],
#         [ 4.6939, -1.5477, -3.3164]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.5045, device='cuda:0')
# Loss.item: 0.5045326948165894
# During training one batch, the logits of the output is: tensor([[-2.2817,  5.5865, -3.3921],
#         [-1.6921, -2.8984,  4.9041],
#         [-2.1212,  5.6547, -3.5150],
#         [-2.5841,  5.8797, -3.2610],
#         [-2.4054, -2.5015,  5.0014],
#         [-1.8698, -2.4131,  4.7442],
#         [ 1.6195,  2.4683, -4.0946],
#         [-2.8379,  5.6728, -2.9169],
#         [-2.2764,  5.2301, -3.1441],
#         [-0.1891,  4.4819, -4.1299]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(1.6824, device='cuda:0')
# Loss.item: 1.6823772192001343
# During training one batch, the logits of the output is: tensor([[-2.2627,  5.6257, -3.4424],
#         [-0.9581,  4.6639, -3.7183],
#         [ 4.0055, -0.0739, -3.8962],
#         [-2.3996,  4.6815, -2.4144],
#         [-2.4398,  5.6151, -3.2817],
#         [-2.6744,  5.8433, -3.1815],
#         [-2.2979,  5.5882, -3.3994],
#         [-2.3605, -2.4847,  5.0542],
#         [-2.4061,  5.5975, -3.2976],
#         [-2.7696,  5.8002, -3.0532]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(1.5603, device='cuda:0')
# Loss.item: 1.560318946838379
# During training one batch, the logits of the output is: tensor([[-2.1712, -2.5761,  4.9803],
#         [ 0.9810, -2.4847,  0.9255],
#         [-2.4088, -2.4969,  5.0469],
#         [ 4.5122, -2.6495, -2.3522],
#         [-2.4492,  5.7826, -3.3627],
#         [-1.9248,  5.2785, -3.4638],
#         [-2.1282,  5.6362, -3.5904],
#         [-1.1247,  4.9192, -3.6682],
#         [-2.1448, -2.7007,  5.0162],
#         [ 1.5185, -0.6445, -1.8906]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.7311, device='cuda:0')
# Loss.item: 0.7310947179794312
# During training one batch, the logits of the output is: tensor([[-2.6654,  5.7945, -3.1680],
#         [ 4.2315, -2.1783, -2.7944],
#         [ 1.4760, -4.0461,  2.7300],
#         [ 2.5631, -4.3613,  1.8683],
#         [ 3.0849, -4.2456,  1.4313],
#         [-2.4259,  5.4557, -3.2205],
#         [-1.9775,  5.2222, -3.3586],
#         [-2.8207, -1.8846,  4.7098],
#         [-2.4449,  5.7677, -3.3661],
#         [ 4.5342, -1.9347, -2.6242]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.8249, device='cuda:0')
# Loss.item: 0.8248526453971863
# During training one batch, the logits of the output is: tensor([[-1.2712,  5.2011, -3.8331],
#         [ 3.8841, -2.5713, -2.0002],
#         [ 3.6109, -2.1959, -2.2651],
#         [-2.6022,  5.9020, -3.2474],
#         [-1.7540,  5.3206, -3.5182],
#         [-1.9664,  5.5067, -3.5775],
#         [-2.4925,  5.3545, -2.8756],
#         [ 4.4396, -2.4439, -2.7047],
#         [-1.8202, -2.7760,  4.8884],
#         [-2.2398,  5.5634, -3.3846]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(2.3729, device='cuda:0')
# Loss.item: 2.372896671295166
# During training one batch, the logits of the output is: tensor([[ 4.9856, -2.3761, -2.6299],
#         [-1.4345,  4.6152, -3.2601],
#         [ 4.3717, -3.8849, -0.7348],
#         [-2.2536,  5.3983, -3.2561],
#         [-2.2470,  5.5209, -3.3667],
#         [ 1.9072,  0.0231, -1.9032],
#         [-1.6544, -2.7495,  4.8526],
#         [-2.0420,  5.3414, -3.4246],
#         [ 4.9451, -2.9855, -2.0205],
#         [-2.4587,  5.1169, -2.7858]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.0806, device='cuda:0')
# Loss.item: 0.08063692599534988
# During training one batch, the logits of the output is: tensor([[-2.2153e+00,  5.5287e+00, -3.4405e+00],
#         [-2.1848e+00, -2.6858e+00,  5.0143e+00],
#         [-2.4060e+00,  5.6888e+00, -3.3363e+00],
#         [-2.0125e+00,  5.4643e+00, -3.5011e+00],
#         [-2.5060e+00,  5.8532e+00, -3.3352e+00],
#         [-2.5642e+00,  5.7101e+00, -3.2182e+00],
#         [ 3.0304e-03,  2.1554e+00, -2.2693e+00],
#         [-2.2614e+00,  5.7143e+00, -3.5186e+00],
#         [ 5.0458e+00, -3.5342e+00, -1.3401e+00],
#         [ 1.0495e+00,  1.0075e+00, -3.1755e+00]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.5496, device='cuda:0')
# Loss.item: 0.5495607852935791
# During training one batch, the logits of the output is: tensor([[-1.7552,  5.5514, -3.7126],
#         [-2.1541,  5.0813, -3.0616],
#         [-1.5047, -2.9147,  4.7924],
#         [-2.0098,  5.4483, -3.4974],
#         [-1.1187, -2.3538,  3.5332],
#         [-1.9647, -2.7434,  4.9117],
#         [-2.4334,  5.7801, -3.3271],
#         [ 4.9815, -2.5853, -2.4283],
#         [-0.9212, -3.3469,  4.5492],
#         [-2.1483,  5.5765, -3.4869]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(1.0642, device='cuda:0')
# Loss.item: 1.064194917678833
# During training one batch, the logits of the output is: tensor([[ 2.0630, -0.8728, -2.3017],
#         [-2.6127,  5.6777, -3.1924],
#         [-1.9062,  5.7221, -3.6547],
#         [-2.3217,  5.0990, -2.9217],
#         [-2.3082,  5.5222, -3.3266],
#         [-2.9928,  5.2530, -2.4121],
#         [-2.1721,  5.4403, -3.3526],
#         [-2.0869,  4.3306, -2.3224],
#         [-2.0617,  5.3386, -3.3900],
#         [-0.6579, -3.2808,  4.4384]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(1.6252, device='cuda:0')
# Loss.item: 1.6252222061157227
# During training one batch, the logits of the output is: tensor([[-2.3198,  5.6553, -3.3945],
#         [ 4.2975, -1.9025, -2.5448],
#         [-1.2287,  3.8083, -2.7466],
#         [-2.1695,  5.6259, -3.4736],
#         [-2.8890,  5.8156, -2.9548],
#         [ 1.5185, -0.6445, -1.8906],
#         [-2.1050,  5.0554, -3.1716],
#         [ 3.9184, -0.9351, -2.9169],
#         [-2.0407,  5.0519, -3.1756],
#         [-2.4448,  5.7482, -3.2705]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.0017, device='cuda:0')
# Loss.item: 0.001665494404733181
# During training one batch, the logits of the output is: tensor([[ 4.7200, -2.2618, -2.7894],
#         [-1.6993, -3.1680,  4.9949],
#         [-2.2049,  5.5821, -3.4661],
#         [ 3.7185, -1.9456, -2.6583],
#         [-2.3599,  5.6562, -3.3630],
#         [-2.6776,  5.4901, -2.8901],
#         [-2.6004, -1.3421,  4.4694],
#         [-1.7992,  5.2766, -3.4418],
#         [-2.1730,  5.2644, -3.2117],
#         [ 4.7398, -2.7818, -2.3614]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.0265, device='cuda:0')
# Loss.item: 0.02653736248612404
# During training one batch, the logits of the output is: tensor([[-1.9130,  5.2353, -3.4165],
#         [-2.3209, -2.6437,  5.0486],
#         [-2.3247,  5.6496, -3.3110],
#         [-2.4708,  5.6224, -3.2666],
#         [-2.1728,  5.4158, -3.4283],
#         [-2.2991,  5.8793, -3.5103],
#         [-2.3790,  5.8232, -3.4079],
#         [-2.4180,  5.7216, -3.3883],
#         [-2.4170,  5.6519, -3.3094],
#         [ 0.1010,  1.5749, -1.1117]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(2.4079, device='cuda:0')
# Loss.item: 2.407865524291992
# During training one batch, the logits of the output is: tensor([[-1.4412,  4.4438, -3.0710],
#         [-2.3832,  5.7219, -3.2717],
#         [-2.1395,  5.6079, -3.5336],
#         [-1.9434, -2.8400,  4.9950],
#         [-2.1767,  5.6375, -3.5109],
#         [-2.1958,  5.6865, -3.5342],
#         [-2.3933,  5.8023, -3.4092],
#         [-2.1363,  5.3803, -3.1734],
#         [ 1.0183,  2.2737, -3.4644],
#         [-2.4372,  5.8057, -3.3801]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(1.0881, device='cuda:0')
# Loss.item: 1.088133454322815
# During training one batch, the logits of the output is: tensor([[ 4.2125, -0.7386, -3.4662],
#         [-2.6775,  5.3171, -2.9094],
#         [-2.4462,  5.6873, -3.3045],
#         [ 4.5099, -1.7889, -3.1126],
#         [-1.6175,  5.1862, -3.6222],
#         [ 4.7153, -2.7546, -2.2201],
#         [ 3.4497, -3.7140,  0.6205],
#         [-1.8490,  5.2899, -3.4411],
#         [-2.4738,  5.7906, -3.3416],
#         [ 3.5978, -3.5770, -0.0450]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.5589, device='cuda:0')
# Loss.item: 0.5588616132736206
# During training one batch, the logits of the output is: tensor([[-2.0159,  4.7953, -3.0586],
#         [-1.9694,  5.3018, -3.4349],
#         [-2.2266,  5.4243, -3.2905],
#         [ 4.8561, -3.2841, -1.8041],
#         [ 4.4948, -3.6027, -1.0761],
#         [-0.7220,  4.6219, -3.8891],
#         [ 4.8811, -2.2591, -2.8864],
#         [-2.3340,  4.6415, -2.5367],
#         [-2.0477,  5.4130, -3.4024],
#         [-2.3729,  5.5378, -3.2064]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(1.5327, device='cuda:0')
# Loss.item: 1.5326563119888306
# During training one batch, the logits of the output is: tensor([[-2.1625,  5.7530, -3.5953],
#         [-2.2683,  5.4468, -3.2130],
#         [-1.9720, -2.5599,  4.8666],
#         [-1.4293,  4.7366, -3.3632],
#         [-0.0702, -3.8557,  4.1422],
#         [-2.8395,  5.7082, -2.9015],
#         [-0.6762, -3.5182,  4.4585],
#         [-2.3844,  5.6129, -3.2060],
#         [-1.1090,  4.3031, -3.1150],
#         [-1.9504,  5.6281, -3.5735]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(1.5344, device='cuda:0')
# Loss.item: 1.5343834161758423
# During training one batch, the logits of the output is: tensor([[-2.4249,  5.6857, -3.3338],
#         [-2.7503,  5.7011, -3.0153],
#         [-0.3104, -3.4415,  4.0805],
#         [ 0.2077,  2.9011, -2.8586],
#         [-2.0713, -2.8706,  4.9800],
#         [-2.3298,  5.4037, -3.2225],
#         [ 4.2268, -2.0616, -2.8114],
#         [-1.9891,  5.2892, -3.3743],
#         [-2.5382,  5.7410, -3.1960],
#         [-2.3741,  5.7829, -3.4316]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.4528, device='cuda:0')
# Loss.item: 0.4528457522392273
# During training one batch, the logits of the output is: tensor([[-2.1537, -2.7879,  5.0183],
#         [-2.6034,  5.5353, -3.1008],
#         [-2.9148,  5.6219, -2.8123],
#         [ 0.4429,  3.4444, -3.6728],
#         [-1.9573,  4.8811, -3.1356],
#         [-1.8609, -2.6948,  4.9399],
#         [-1.8569,  5.6083, -3.7157],
#         [ 4.7979, -1.8472, -3.0725],
#         [-1.0086,  4.2673, -3.3248],
#         [ 0.4009, -0.5134, -0.6985]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(1.6109, device='cuda:0')
# Loss.item: 1.6109098196029663
# During training one batch, the logits of the output is: tensor([[ 5.1213, -3.3708, -1.3110],
#         [-1.8547,  5.5221, -3.5299],
#         [-2.5667,  5.5006, -2.8575],
#         [-1.9223, -2.9605,  5.0005],
#         [ 0.1884,  3.7498, -3.8227],
#         [-2.1761,  5.4873, -3.3571],
#         [ 4.3582, -0.7710, -3.2709],
#         [-2.4582,  5.6118, -3.2331],
#         [-2.2204,  5.5780, -3.4190],
#         [-2.0625,  5.4592, -3.5042]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(1.9631, device='cuda:0')
# Loss.item: 1.9630892276763916
# During training one batch, the logits of the output is: tensor([[-2.4190, -2.5238,  5.0210],
#         [-2.1001,  5.5339, -3.4158],
#         [ 5.0148, -2.5696, -2.6470],
#         [-2.8110,  5.1793, -2.5637],
#         [-2.1850,  5.5857, -3.4535],
#         [ 2.8360, -2.2760, -1.4471],
#         [ 1.0459,  2.4066, -3.6020],
#         [-1.9526,  4.6717, -2.5522],
#         [-1.7271,  5.5644, -3.7907],
#         [ 4.3493, -4.3423,  0.2685]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.5802, device='cuda:0')
# Loss.item: 0.580180287361145
# During training one batch, the logits of the output is: tensor([[-2.1251,  5.4624, -3.4656],
#         [ 4.5666, -2.3420, -2.8085],
#         [-2.2289,  5.4998, -3.3531],
#         [-2.3757,  5.4584, -3.1617],
#         [-2.3768,  5.3789, -3.1561],
#         [-1.8579, -3.0417,  4.9697],
#         [-2.1581,  5.6018, -3.4983],
#         [ 5.0038, -2.0140, -3.0145],
#         [-1.1185,  4.6597, -3.5768],
#         [-0.3388,  4.0321, -3.6335]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(1.3479, device='cuda:0')
# Loss.item: 1.3479173183441162
# During training one batch, the logits of the output is: tensor([[-2.2996,  5.6730, -3.3872],
#         [-0.4715, -0.0698,  1.2184],
#         [ 4.5588, -3.2848, -1.6724],
#         [ 2.6512, -0.5223, -2.1331],
#         [-2.5568,  5.7502, -3.2672],
#         [-2.4713,  5.3783, -2.9477],
#         [-1.8694,  5.6681, -3.7352],
#         [-2.6344,  5.3568, -2.8195],
#         [ 4.4595, -2.4421, -2.6501],
#         [ 4.3455, -3.1246, -1.1030]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(1.6002, device='cuda:0')
# Loss.item: 1.6001813411712646
# During training one batch, the logits of the output is: tensor([[ 4.3562, -0.8673, -3.1194],
#         [-2.2490,  5.4681, -3.3500],
#         [-0.7188, -3.0002,  4.2594],
#         [-2.2757,  5.5886, -3.3304],
#         [-1.2856, -1.3481,  3.3800],
#         [-1.6299, -2.9600,  4.9089],
#         [-2.2996, -2.5696,  5.0158],
#         [-2.5025,  5.8016, -3.3033],
#         [ 0.2528,  0.6457, -0.8471],
#         [-2.1198,  5.0118, -2.7458]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(2.4423, device='cuda:0')
# Loss.item: 2.4422929286956787
# During training one batch, the logits of the output is: tensor([[ 3.6401, -4.2041,  0.1658],
#         [-2.1378,  5.5642, -3.4245],
#         [-2.5720, -1.7491,  4.6707],
#         [ 4.1703, -2.1866, -1.6238],
#         [ 4.0199, -4.3048,  0.2941],
#         [-2.4229,  5.2969, -2.9967],
#         [ 4.6834, -2.1345, -2.9401],
#         [-2.7908,  5.7122, -2.9830],
#         [-1.1054,  4.1076, -3.2465],
#         [-2.3745,  5.6330, -3.3830]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.0083, device='cuda:0')
# Loss.item: 0.00830302108079195
# During training one batch, the logits of the output is: tensor([[-2.7356,  5.6514, -3.0360],
#         [-2.2349,  5.6893, -3.4555],
#         [-1.8169, -2.9823,  4.9920],
#         [ 4.8571, -2.3434, -2.8019],
#         [-2.4268,  5.8125, -3.3858],
#         [-0.4459,  3.0674, -2.3051],
#         [ 4.6832, -2.5403, -2.0916],
#         [-0.6420,  2.6945, -2.2736],
#         [-2.0923,  5.5086, -3.4814],
#         [-2.2670, -2.6385,  5.0303]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.8350, device='cuda:0')
# Loss.item: 0.8350443840026855
# During training one batch, the logits of the output is: tensor([[-1.6084,  4.6598, -3.0283],
#         [-1.1097,  5.2386, -3.9970],
#         [ 0.2807, -3.2705,  2.9353],
#         [ 5.1445, -2.8427, -2.0109],
#         [-2.3846,  5.6195, -3.3111],
#         [-2.3801,  5.6728, -3.2690],
#         [-2.2284,  5.6644, -3.4984],
#         [-2.2712,  5.5943, -3.3961],
#         [-2.0798,  5.2301, -3.2415],
#         [-2.2177,  5.1788, -3.0928]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(1.4863, device='cuda:0')
# Loss.item: 1.4863407611846924
# During training one batch, the logits of the output is: tensor([[-1.9542,  5.6403, -3.6556],
#         [-0.0686, -3.5575,  4.1709],
#         [-0.8428, -3.3281,  4.5297],
#         [ 0.2807, -3.2705,  2.9353],
#         [-2.2645,  5.3536, -3.2243],
#         [-1.8359,  4.3557, -2.4878],
#         [-1.8547,  4.5034, -2.5103],
#         [-2.6824,  5.6544, -3.1017],
#         [ 0.3093, -3.6542,  3.9143],
#         [ 4.7402, -2.2690, -2.8160]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(1.6003, device='cuda:0')
# Loss.item: 1.6002864837646484
# During training one batch, the logits of the output is: tensor([[-2.0185,  5.0253, -3.1685],
#         [-1.7684,  5.1813, -3.4449],
#         [-2.3830,  5.7906, -3.4168],
#         [-1.5097,  5.4657, -3.8162],
#         [-2.2625, -2.6291,  5.0388],
#         [-1.7319, -2.9543,  4.9152],
#         [-1.5461, -3.1406,  4.9062],
#         [-2.2611,  5.5575, -3.4010],
#         [-2.6728,  3.3763, -0.7027],
#         [-0.9952, -3.1233,  4.4434]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(1.3592, device='cuda:0')
# Loss.item: 1.359195351600647
# During training one batch, the logits of the output is: tensor([[ 0.7913,  2.4113, -3.5163],
#         [-2.5228,  5.7405, -3.1835],
#         [-1.7541,  5.4325, -3.6962],
#         [ 0.6794, -1.3865,  1.6465],
#         [ 3.8109, -3.6291, -0.0139],
#         [-1.8903,  5.1609, -3.3058],
#         [-2.3207,  5.6799, -3.4291],
#         [-2.2960,  5.6871, -3.3115],
#         [ 0.9017, -1.5221,  0.5537],
#         [-2.0875, -2.7501,  5.0062]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(1.4518, device='cuda:0')
# Loss.item: 1.4517629146575928
# During training one batch, the logits of the output is: tensor([[-2.3326,  5.2948, -3.0175],
#         [-2.0945,  5.5202, -3.4702],
#         [-2.7855,  5.2571, -2.5972],
#         [-1.9478,  5.4725, -3.5576],
#         [-0.2004,  3.5592, -2.7135],
#         [-2.0844,  5.3453, -3.3964],
#         [-2.0953,  4.7077, -2.8874],
#         [-2.1074,  5.5755, -3.3900],
#         [-2.0750,  5.5920, -3.6025],
#         [-2.1532,  5.5572, -3.4786]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(2.0742, device='cuda:0')
# Loss.item: 2.0741524696350098
# During training one batch, the logits of the output is: tensor([[ 1.8784, -0.7503, -2.2242],
#         [ 0.3755,  0.6120, -0.8548],
#         [-1.2091, -3.3869,  4.7878],
#         [ 4.8910, -2.4572, -2.6582],
#         [-1.9778,  5.3287, -3.4035],
#         [-2.3078,  5.6947, -3.4518],
#         [-2.3839,  4.5096, -2.3111],
#         [-2.8879,  5.6241, -2.8676],
#         [-2.1216,  5.2680, -3.2472],
#         [-1.4990, -3.0295,  4.7754]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.0006, device='cuda:0')
# Loss.item: 0.0005873157060705125
# During training one batch, the logits of the output is: tensor([[-2.3463,  5.7050, -3.4450],
#         [-2.6284,  5.8928, -3.1983],
#         [-2.5790,  5.8601, -3.2919],
#         [-2.7930,  4.9828, -2.3313],
#         [-2.2554,  5.6351, -3.4563],
#         [-2.2322,  5.6724, -3.2801],
#         [-2.1302,  5.5737, -3.5447],
#         [-2.5612,  5.7281, -3.2062],
#         [ 5.1669, -3.1845, -1.7184],
#         [-2.4638,  5.4788, -3.1028]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.2331, device='cuda:0')
# Loss.item: 0.23312826454639435
# During training one batch, the logits of the output is: tensor([[-2.3183,  5.5924, -3.4039],
#         [-2.3777,  5.7501, -3.4087],
#         [-2.2889,  5.7375, -3.4849],
#         [ 1.5185, -0.6445, -1.8906],
#         [-2.4837,  5.6547, -3.2873],
#         [-2.0867, -2.5514,  4.8994],
#         [-2.3048,  5.6345, -3.3391],
#         [-1.2926,  4.2783, -2.8687],
#         [ 4.5697, -3.7858, -0.5086],
#         [ 3.3932, -1.9852, -1.1220]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.8469, device='cuda:0')
# Loss.item: 0.8469058871269226
# During training one batch, the logits of the output is: tensor([[ 4.8548, -1.9507, -3.0492],
#         [-2.2368,  5.5553, -3.4280],
#         [-2.9971,  0.4212,  3.1745],
#         [-1.5211,  2.8603, -1.4252],
#         [-2.3610,  5.4372, -3.1073],
#         [-1.5417,  5.4366, -3.7462],
#         [-2.0759, -2.5908,  4.9684],
#         [-1.7185,  4.5167, -3.0614],
#         [ 0.8194,  1.7224, -2.3318],
#         [-0.2241,  2.4520, -1.9939]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.4227, device='cuda:0')
# Loss.item: 0.4227287769317627
# During training one batch, the logits of the output is: tensor([[-2.1738, -2.6239,  4.9835],
#         [-2.5773,  5.8819, -3.3000],
#         [-2.4958,  5.7783, -3.2837],
#         [ 4.0883, -0.1177, -3.7336],
#         [-1.5966,  5.1473, -3.5453],
#         [-1.9226,  5.3405, -3.5173],
#         [-2.4737,  5.6074, -3.2484],
#         [-2.2330,  5.3619, -3.2283],
#         [-2.4083,  5.6538, -3.3105],
#         [-2.3983,  5.6924, -3.3484]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(2.0508, device='cuda:0')
# Loss.item: 2.05081844329834
# During training one batch, the logits of the output is: tensor([[-2.3621,  5.5565, -3.3375],
#         [-2.1241,  5.5266, -3.4965],
#         [-2.1305,  5.4932, -3.4813],
#         [-2.9437,  4.7421, -1.7384],
#         [-2.0153,  5.5977, -3.6049],
#         [-2.1973,  5.3708, -3.2605],
#         [-2.3691,  5.8083, -3.4832],
#         [-1.6430,  4.7086, -3.1475],
#         [ 1.7391, -3.6707,  2.4436],
#         [ 0.0488, -3.8067,  4.0419]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.7220, device='cuda:0')
# Loss.item: 0.7220481634140015
# During training one batch, the logits of the output is: tensor([[-1.6576,  5.2742, -3.6511],
#         [-2.3040,  5.5632, -3.3673],
#         [-2.1363,  5.2557, -3.2504],
#         [ 4.9096, -1.5528, -3.2285],
#         [-2.4960,  5.6461, -3.1688],
#         [-2.2940,  5.7030, -3.4579],
#         [-1.9615, -2.4493,  4.7605],
#         [-1.8802,  4.8242, -3.1127],
#         [-1.4746,  5.1514, -3.6300],
#         [-2.2317,  5.5892, -3.4421]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(1.3005, device='cuda:0')
# Loss.item: 1.3005435466766357
# During training one batch, the logits of the output is: tensor([[-1.5400, -3.0592,  4.8952],
#         [-2.3898,  5.6036, -3.2648],
#         [-2.5226,  5.4573, -3.0486],
#         [ 4.0752, -2.4450, -2.3434],
#         [ 1.5185, -0.6445, -1.8906],
#         [ 4.6631, -1.7289, -2.9976],
#         [-2.3737,  5.8875, -3.3935],
#         [-1.7040, -2.9745,  4.9140],
#         [-1.7527,  4.7775, -3.1347],
#         [ 4.6681, -2.1860, -2.9608]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(1.5167, device='cuda:0')
# Loss.item: 1.5167187452316284
# During training one batch, the logits of the output is: tensor([[-1.3697, -2.7677,  4.3797],
#         [-2.5100,  5.7771, -3.3229],
#         [-1.8787,  5.5219, -3.6544],
#         [-2.3607,  5.6784, -3.3693],
#         [-2.7194,  5.6788, -3.1093],
#         [-1.9637, -2.9979,  5.0063],
#         [-2.4336,  5.8128, -3.3770],
#         [-2.2556,  5.7410, -3.4447],
#         [ 4.4806, -3.9093, -0.2099],
#         [ 4.5754, -3.9318, -0.5724]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.4347, device='cuda:0')
# Loss.item: 0.4347211718559265
# During training one batch, the logits of the output is: tensor([[-2.4547,  5.8483, -3.3573],
#         [-1.2386, -3.1291,  4.6518],
#         [ 2.2242,  1.0706, -3.0267],
#         [-2.6295,  5.8173, -3.1916],
#         [-2.2633,  5.7380, -3.4388],
#         [-2.4583,  5.7147, -3.3219],
#         [-2.4566,  5.8515, -3.2934],
#         [-2.6065,  5.4223, -2.9737],
#         [ 0.7581,  3.6112, -4.3165],
#         [-2.6135,  5.8037, -3.1979]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.0012, device='cuda:0')
# Loss.item: 0.0011517411330714822
# During training one batch, the logits of the output is: tensor([[-3.0145,  5.1290, -2.3135],
#         [-2.5469,  5.6899, -3.2459],
#         [-2.4543,  5.8262, -3.3627],
#         [-2.3754, -2.4669,  5.0021],
#         [-2.2984,  5.7266, -3.4365],
#         [-0.9160, -3.4712,  4.6341],
#         [-2.5589,  5.8565, -3.2689],
#         [-1.8012, -3.0286,  4.9677],
#         [ 4.5914, -2.7390, -2.0999],
#         [-2.4045,  5.8126, -3.3782]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.6288, device='cuda:0')
# Loss.item: 0.6287544369697571
# During training one batch, the logits of the output is: tensor([[ 4.5782, -2.6755, -2.4222],
#         [ 4.3759, -2.0446, -2.9204],
#         [ 0.4606,  3.4041, -3.8759],
#         [-1.5537,  4.4826, -3.0005],
#         [-2.3803,  5.8071, -3.4337],
#         [-2.4472, -2.4863,  4.9973],
#         [-3.2535,  2.0876,  1.6654],
#         [ 3.3759, -1.9129, -2.4141],
#         [-2.2711,  5.5605, -3.4050],
#         [-1.9879,  5.7216, -3.7164]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(2.1644, device='cuda:0')
# Loss.item: 2.164424180984497
# During training one batch, the logits of the output is: tensor([[ 4.7257, -1.5940, -3.2910],
#         [-2.3363, -2.4598,  4.9913],
#         [-2.3668,  5.7561, -3.4384],
#         [-2.1845, -2.6672,  4.9869],
#         [-0.2686,  3.6309, -3.4673],
#         [-2.4433,  5.7779, -3.2965],
#         [-0.7952, -3.1815,  4.2106],
#         [ 2.3879,  0.5401, -3.0943],
#         [-2.4590, -1.8308,  4.6942],
#         [-2.1342,  5.5188, -3.4411]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.3110, device='cuda:0')
# Loss.item: 0.311038076877594
# During training one batch, the logits of the output is: tensor([[-2.4191,  5.5408, -3.3019],
#         [-2.3887,  5.7736, -3.3867],
#         [ 3.8354, -2.3938, -2.2924],
#         [ 0.0488, -3.8067,  4.0419],
#         [-2.5188,  5.7978, -3.3093],
#         [ 0.7294,  0.9920, -1.6929],
#         [ 0.4292,  2.7989, -3.4683],
#         [-2.5355,  5.8959, -3.3002],
#         [-2.4846,  5.7202, -3.3075],
#         [ 3.5736, -0.5687, -3.5522]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(1.3340, device='cuda:0')
# Loss.item: 1.33400297164917
# During training one batch, the logits of the output is: tensor([[ 1.0028,  1.1081, -3.0577],
#         [-2.4715,  5.7146, -3.3142],
#         [-2.6716,  4.1126, -1.6127],
#         [-2.3784,  5.4873, -3.2222],
#         [-1.1700,  5.0875, -3.8739],
#         [-2.2073,  5.5919, -3.4495],
#         [ 2.3352, -4.5685,  2.3266],
#         [-2.6838,  5.7651, -3.1155],
#         [-2.5559,  5.8056, -3.2976],
#         [-2.0046,  5.4654, -3.4567]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(1.3289, device='cuda:0')
# Loss.item: 1.3288524150848389
# During training one batch, the logits of the output is: tensor([[-2.5473,  5.7168, -3.2089],
#         [ 3.7300, -2.4456, -2.0243],
#         [ 1.5185, -0.6445, -1.8906],
#         [-1.7926, -2.8478,  4.8887],
#         [-2.5300,  5.6659, -3.2055],
#         [ 1.0794,  2.3116, -3.3536],
#         [-2.0467,  5.6290, -3.5476],
#         [-1.7231,  5.6262, -3.8456],
#         [-2.3427,  5.5860, -3.3487],
#         [ 4.9542, -3.1709, -1.8161]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(1.8826, device='cuda:0')
# Loss.item: 1.8826020956039429
# During training one batch, the logits of the output is: tensor([[-1.2025, -3.2009,  4.6707],
#         [-2.4515,  5.7887, -3.3392],
#         [ 4.3214, -4.0814, -0.1375],
#         [-1.0772,  1.7396, -0.8283],
#         [-2.6988,  5.6991, -3.0931],
#         [-1.5054,  5.0660, -3.5588],
#         [-2.4311,  5.2076, -2.8678],
#         [-1.1385,  2.8476, -1.8648],
#         [-1.9369,  5.3253, -3.4437],
#         [-2.6858,  5.7531, -3.1343]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(2.6948, device='cuda:0')
# Loss.item: 2.6948044300079346
# During training one batch, the logits of the output is: tensor([[-2.0863,  5.3919, -3.4360],
#         [-2.3038,  5.6004, -3.3364],
#         [-2.1097, -2.4656,  4.8606],
#         [-1.0829,  1.2985, -0.0180],
#         [ 4.8656, -1.8880, -3.0980],
#         [-0.6586,  4.4292, -3.6977],
#         [-1.4947, -3.1267,  4.8597],
#         [-2.3111,  5.6654, -3.4363],
#         [-1.4944,  5.2688, -3.6828],
#         [ 2.6222, -2.2864,  0.0766]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(1.0773, device='cuda:0')
# Loss.item: 1.0773084163665771
# During training one batch, the logits of the output is: tensor([[-2.1305,  5.6233, -3.5260],
#         [-1.2348,  3.6579, -2.7627],
#         [-2.4787,  5.8399, -3.3279],
#         [-2.1745,  5.4983, -3.4575],
#         [-2.2142,  5.6659, -3.4452],
#         [-2.3316,  5.6683, -3.4112],
#         [-2.5814,  5.8603, -3.3068],
#         [-2.4757,  5.9128, -3.3623],
#         [ 4.0032, -1.8583, -2.9180],
#         [ 4.4200, -3.2577, -1.5633]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(1.4614, device='cuda:0')
# Loss.item: 1.4613858461380005
# During training one batch, the logits of the output is: tensor([[-2.5518,  5.8270, -3.3184],
#         [-1.3699, -3.0216,  4.7397],
#         [-2.3097,  5.7259, -3.4659],
#         [-2.6170,  5.8457, -3.2557],
#         [-2.4748,  5.4164, -3.0324],
#         [ 4.2259, -1.6063, -3.2290],
#         [-0.6790,  1.4683, -1.1509],
#         [ 1.2847,  2.3983, -4.0935],
#         [-2.3309,  5.7060, -3.4453],
#         [-2.5265,  5.7877, -3.3120]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(2.0009, device='cuda:0')
# Loss.item: 2.0008742809295654
# ...
# During training one batch, the loss of the output is: tensor(0.0011, device='cuda:0')
# Loss.item: 0.001075419713743031
# During training one batch, the logits of the output is: tensor([[-1.8318,  5.6798, -3.6929],
#         [-2.5910,  5.8034, -3.2740],
#         [-2.3496, -2.5391,  5.0313],
#         [-2.4977,  5.5462, -3.1760],
#         [-1.1955,  4.4825, -3.3768],
#         [-2.1334,  5.7761, -3.5407],
#         [-2.4071, -2.3404,  4.9628],
#         [ 4.5565, -2.5705, -2.4439],
#         [-2.5114,  5.8482, -3.3475],
#         [-2.1491,  5.5985, -3.4186]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.8591, device='cuda:0')
# Loss.item: 0.8591392636299133
# During training one batch, the logits of the output is: tensor([[-1.2825,  4.8953, -3.5355],
#         [ 2.7685, -1.4606, -2.2118],
#         [ 3.7185, -1.9456, -2.6583],
#         [-2.2713, -2.6153,  5.0395],
#         [-2.4399,  5.7899, -3.3947],
#         [-1.7955, -1.8319,  4.0731],
#         [ 4.4312, -2.4714, -2.0775],
#         [-2.9320,  0.7593,  2.8319],
#         [-2.0319,  5.4788, -3.2633],
#         [-2.3933,  5.7047, -3.3452]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.6041, device='cuda:0')
# Loss.item: 0.6041274070739746
# During training one batch, the logits of the output is: tensor([[-2.2360,  5.6952, -3.5138],
#         [-2.3406,  5.6678, -3.4016],
#         [-2.9367,  5.0657, -2.2495],
#         [ 3.8776, -1.7430, -2.8989],
#         [-2.9205,  5.4190, -2.6521],
#         [-2.2122,  5.7987, -3.4472],
#         [-2.1173,  5.6701, -3.4563],
#         [-2.5844, -1.5242,  4.5040],
#         [-2.3539,  5.7553, -3.4328],
#         [-2.0933, -2.7945,  5.0346]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(1.3306, device='cuda:0')
# Loss.item: 1.330635905265808
# During training one batch, the logits of the output is: tensor([[ 0.2946,  3.7361, -3.7826],
#         [-2.4371,  5.7334, -3.3446],
#         [-1.9293,  5.2036, -3.3563],
#         [-2.3165,  5.8347, -3.3801],
#         [ 4.6792, -1.9373, -2.9201],
#         [-2.0766, -2.8154,  4.9946],
#         [-2.2385,  5.1850, -3.0943],
#         [-1.4109,  4.7214, -3.4638],
#         [-2.2451,  5.6985, -3.4033],
#         [-2.2799,  5.5596, -3.3766]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(1.0095, device='cuda:0')
# Loss.item: 1.0095078945159912
# During training one batch, the logits of the output is: tensor([[ 2.8195,  0.3259, -2.8214],
#         [-2.4103,  5.7386, -3.3720],
#         [ 4.6066, -2.4053, -2.5628],
#         [-1.4502, -2.7671,  4.7042],
#         [ 4.9618, -2.5389, -2.6212],
#         [-2.3419,  3.7484, -0.9739],
#         [-2.4136,  5.6842, -3.3144],
#         [-2.5704,  5.7154, -3.2105],
#         [ 3.4062, -1.5624, -2.0343],
#         [ 0.0488, -3.8067,  4.0419]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.0180, device='cuda:0')
# Loss.item: 0.018046561628580093
# During training one batch, the logits of the output is: tensor([[-2.9214,  4.3364, -1.2492],
#         [ 3.6887,  0.0810, -4.1169],
#         [ 0.6022,  4.2792, -4.4721],
#         [ 4.8617, -2.0828, -2.7857],
#         [ 1.0079,  3.0860, -3.9882],
#         [-2.3908,  5.8047, -3.4245],
#         [ 5.0970, -2.3587, -2.2538],
#         [-2.4418,  5.8014, -3.3325],
#         [-2.4017, -2.4996,  5.0411],
#         [-2.1962,  5.5979, -3.5108]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.6001, device='cuda:0')
# Loss.item: 0.600143313407898
# During training one batch, the logits of the output is: tensor([[-1.9083,  4.6846, -2.9278],
#         [-2.7124,  5.8899, -3.0736],
#         [-2.0935,  5.5788, -3.4961],
#         [-2.4605,  5.7384, -3.3069],
#         [-1.3224,  4.6705, -3.1476],
#         [-2.6226,  5.7077, -3.1290],
#         [-2.3281,  5.6132, -3.3910],
#         [-2.2267,  5.6867, -3.4799],
#         [-2.7100,  5.5408, -2.8940],
#         [-1.9836,  5.5087, -3.5905]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(2.0011, device='cuda:0')
# Loss.item: 2.0010714530944824
# During training one batch, the logits of the output is: tensor([[ 1.2473, -0.4270, -1.7478],
#         [-2.3689,  5.6893, -3.3790],
#         [-0.0581,  2.7214, -2.8945],
#         [-2.1969,  5.6444, -3.5249],
#         [ 0.4432, -3.5750,  3.6727],
#         [-2.4330,  5.9129, -3.3779],
#         [-2.3134,  5.7292, -3.4362],
#         [-2.1661,  5.6905, -3.5538],
#         [-2.1913,  5.7821, -3.5087],
#         [ 2.4215,  0.5334, -3.5927]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.7959, device='cuda:0')
# Loss.item: 0.7958927154541016
# During training one batch, the logits of the output is: tensor([[-2.1216,  5.2619, -3.3464],
#         [-2.1951,  5.6544, -3.4421],
#         [-2.6385,  5.3718, -2.8393],
#         [-1.2053,  2.1095, -0.9214],
#         [-2.1658,  5.3786, -3.3174],
#         [-2.3037,  5.6393, -3.4365],
#         [-0.4852,  3.7520, -3.3649],
#         [-1.7343,  5.5294, -3.7228],
#         [-0.4521, -3.6375,  4.3906],
#         [-2.0094,  5.1922, -3.2658]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(2.3741, device='cuda:0')
# Loss.item: 2.374129056930542
# During training one batch, the logits of the output is: tensor([[ 4.6875, -2.3823, -2.7254],
#         [-2.3143,  5.7071, -3.3866],
#         [-1.3219,  4.8143, -3.3838],
#         [ 0.8018, -2.8225,  1.8526],
#         [-2.0622,  0.2481,  2.4824],
#         [-2.6165,  5.9046, -3.2061],
#         [-2.2270,  5.7539, -3.5088],
#         [-2.3391, -2.6136,  5.0516],
#         [-1.8869, -2.9076,  4.9912],
#         [-0.8362,  5.1919, -4.1835]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(2.2424, device='cuda:0')
# Loss.item: 2.242361545562744
# During training one batch, the logits of the output is: tensor([[-1.8963, -2.7615,  4.9177],
#         [ 3.4804, -4.1653,  1.0743],
#         [-2.2378,  5.6643, -3.4676],
#         [ 4.4915, -1.6764, -3.2125],
#         [-1.7959,  4.9397, -3.2988],
#         [-2.2492,  5.7213, -3.4958],
#         [ 5.2204, -2.5969, -2.5978],
#         [ 5.1053, -2.6688, -2.3645],
#         [ 5.1247, -2.9017, -2.1221],
#         [-2.3930,  5.3935, -3.0258]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(1.3656, device='cuda:0')
# Loss.item: 1.36556875705719
# During training one batch, the logits of the output is: tensor([[-2.2714,  5.7028, -3.4558],
#         [-2.3459,  5.7412, -3.3672],
#         [-2.3097,  5.2810, -3.0713],
#         [ 4.8200, -2.0375, -3.0327],
#         [-2.1984,  5.7720, -3.5614],
#         [ 4.7950, -1.7812, -3.1473],
#         [-2.1192,  5.3868, -3.3863],
#         [ 0.0488, -3.8067,  4.0419],
#         [-1.7155,  4.9911, -3.2902],
#         [ 2.9007, -4.3627,  2.0187]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.1210, device='cuda:0')
# Loss.item: 0.12104396522045135
# During training one batch, the logits of the output is: tensor([[-2.3361,  5.8000, -3.4746],
#         [ 3.4551, -2.1746, -1.9752],
#         [-0.6227,  0.1231,  1.5865],
#         [-1.3062,  5.2026, -3.6662],
#         [-2.3812, -2.5478,  5.0057],
#         [-2.6251,  5.8635, -3.2498],
#         [-1.2255,  3.9353, -2.9320],
#         [ 1.8394, -4.4746,  2.2083],
#         [-2.1937, -2.7202,  5.0574],
#         [-1.4342,  4.7576, -3.4143]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.8029, device='cuda:0')
# Loss.item: 0.80287104845047
# During training one batch, the logits of the output is: tensor([[-2.8669,  5.8093, -2.9502],
#         [-2.2658, -2.6582,  5.0005],
#         [-2.3780,  5.7762, -3.3891],
#         [-2.0043,  5.3822, -3.4768],
#         [ 5.1571, -3.1242, -1.9484],
#         [ 4.8334, -2.3609, -2.8313],
#         [-1.4861, -2.7527,  4.6202],
#         [-0.6589, -3.5085,  4.4829],
#         [-3.7854,  3.8310, -0.0202],
#         [-2.2011, -2.2763,  4.7691]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(1.4072, device='cuda:0')
# Loss.item: 1.4072128534317017
# During training one batch, the logits of the output is: tensor([[-2.5505,  5.6353, -3.0968],
#         [ 2.5527, -4.2267,  2.3299],
#         [-1.9841,  5.4602, -3.4869],
#         [-1.9838,  5.2556, -3.3635],
#         [-2.6123,  3.4807, -0.7224],
#         [ 1.9896, -3.8683,  2.2264],
#         [ 4.7441, -3.6878, -0.5918],
#         [-2.2808,  5.6328, -3.4291],
#         [-2.5649,  5.5555, -3.1224],
#         [-2.0112, -2.8290,  4.9583]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.2199, device='cuda:0')
# Loss.item: 0.21991106867790222
# During training one batch, the logits of the output is: tensor([[-2.5238,  5.5141, -2.7457],
#         [ 5.0324, -2.0196, -2.9316],
#         [-2.7952,  5.5888, -2.8858],
#         [ 3.6399, -1.7374, -2.8076],
#         [ 3.1530, -2.0709, -2.0901],
#         [-0.6796,  0.1858,  1.0148],
#         [-2.1973,  5.5551, -3.4274],
#         [-1.8312,  4.8121, -3.1599],
#         [-2.4774,  5.8260, -3.3659],
#         [-2.2663,  5.5574, -3.4230]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.7333, device='cuda:0')
# Loss.item: 0.7333090901374817
# During training one batch, the logits of the output is: tensor([[ 4.0554, -2.7833, -1.5636],
#         [-0.5423,  4.2166, -3.9935],
#         [-1.9717,  5.1811, -3.2706],
#         [-2.4896,  5.7288, -3.3129],
#         [-2.6561,  5.7256, -3.1849],
#         [ 1.5467,  2.5008, -3.9548],
#         [-2.2683, -2.1934,  4.7713],
#         [-2.2695,  5.6493, -3.4510],
#         [ 3.8054, -2.7070, -1.6901],
#         [-1.8704,  5.1116, -3.4491]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.1730, device='cuda:0')
# Loss.item: 0.1730380356311798
# During training one batch, the logits of the output is: tensor([[ 4.5586, -2.9527, -2.0222],
#         [-2.2099, -2.5190,  4.9177],
#         [-2.2591,  5.1012, -2.8971],
#         [-2.3542,  5.7394, -3.3954],
#         [ 1.4099,  2.9314, -4.2017],
#         [-2.4620,  5.5656, -3.2335],
#         [-2.4504,  5.8292, -3.3944],
#         [-2.1618, -2.8041,  5.0315],
#         [-0.9570,  4.7735, -3.8289],
#         [-2.9403,  5.3945, -2.5444]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(1.1360, device='cuda:0')
# Loss.item: 1.1359586715698242
# During training one batch, the logits of the output is: tensor([[-1.6141,  3.3008, -2.0040],
#         [ 1.4074, -3.6605,  2.8073],
#         [-1.4601,  4.9662, -3.5800],
#         [ 0.5546, -3.7572,  3.5821],
#         [-1.7186,  5.6485, -3.7943],
#         [ 3.0669, -0.4581, -3.4050],
#         [-1.9477,  5.6069, -3.6648],
#         [ 4.8124, -2.1961, -2.8506],
#         [-1.8490,  5.4017, -3.6920],
#         [-2.0624,  5.4539, -3.4913]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(1.5132, device='cuda:0')
# Loss.item: 1.5131981372833252
# During training one batch, the logits of the output is: tensor([[-2.5148,  5.4354, -2.8389],
#         [ 5.0342, -2.9929, -2.0424],
#         [ 4.2670, -3.8080, -0.8446],
#         [-1.9982,  4.8747, -2.9399],
#         [-2.5017,  5.6911, -3.2809],
#         [ 4.0705, -1.8167, -2.9691],
#         [-2.1123,  5.7455, -3.6109],
#         [-2.4586,  5.8696, -3.3867],
#         [-2.1621,  5.4212, -3.3687],
#         [ 4.3759, -2.0446, -2.9204]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.9397, device='cuda:0')
# Loss.item: 0.9396553039550781
# During training one batch, the logits of the output is: tensor([[-0.3167,  1.1013, -0.8465],
#         [-2.3124,  5.6512, -3.4118],
#         [-1.4742,  5.1055, -3.7285],
#         [-2.4526,  5.8120, -3.3677],
#         [ 4.9932, -2.6762, -2.3669],
#         [-2.5388,  5.7927, -3.2775],
#         [-1.1373, -2.9651,  4.1288],
#         [-1.8932, -2.7045,  4.7678],
#         [ 3.8138, -2.0583, -2.5817],
#         [ 4.3185, -4.3177, -0.0152]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(2.7622, device='cuda:0')
# Loss.item: 2.7621870040893555
# During training one batch, the logits of the output is: tensor([[-2.6533,  5.8750, -3.1739],
#         [-1.0352, -3.5839,  4.7446],
#         [-2.2442,  5.6494, -3.4599],
#         [-2.2235, -1.5436,  4.3135],
#         [-2.8420,  3.4031, -0.5801],
#         [-2.5868,  5.9088, -3.2843],
#         [-1.9861,  5.6186, -3.6349],
#         [-2.3270,  5.4872, -3.2539],
#         [-1.5797,  5.3748, -3.6993],
#         [-2.3299,  5.3164, -3.1808]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(1.1933, device='cuda:0')
# Loss.item: 1.1932753324508667
# During training one batch, the logits of the output is: tensor([[ 4.0272, -0.4483, -3.8389],
#         [-2.1856,  5.5083, -3.4589],
#         [-2.1858,  5.3444, -3.2882],
#         [ 5.0662, -2.3585, -2.3234],
#         [-1.7620, -3.0165,  4.9688],
#         [-2.3614,  5.4862, -3.2386],
#         [-2.6467,  5.8308, -3.1562],
#         [-0.0702, -3.8557,  4.1422],
#         [-2.1373,  5.6078, -3.5157],
#         [-2.4261,  5.6786, -3.3463]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.3214, device='cuda:0')
# Loss.item: 0.32141032814979553
# During training one batch, the logits of the output is: tensor([[ 1.5185, -0.6445, -1.8906],
#         [-2.6878,  5.7842, -3.1117],
#         [-2.2749,  5.6696, -3.4784],
#         [-2.7652, -0.6707,  3.8879],
#         [ 2.9871,  1.6271, -4.5671],
#         [-2.2997,  5.6099, -3.3833],
#         [-2.1997,  5.5591, -3.4519],
#         [ 4.5643, -2.2644, -2.8437],
#         [ 1.8017, -0.9432, -1.8456],
#         [-2.1779,  5.5066, -3.3780]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.0007, device='cuda:0')
# Loss.item: 0.0006545706419274211
# During training one batch, the logits of the output is: tensor([[-2.2005,  5.7460, -3.5465],
#         [-2.3542,  5.5471, -3.1408],
#         [-2.5023,  5.8935, -3.3556],
#         [ 4.9829, -2.6809, -2.2149],
#         [-2.2795,  5.5509, -3.3783],
#         [ 4.9331, -2.4566, -2.6572],
#         [-2.3707,  5.5031, -3.2634],
#         [-2.2310,  5.7464, -3.4410],
#         [-2.2422,  5.6555, -3.4922],
#         [-2.1555,  5.1647, -3.1342]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(3.1506, device='cuda:0')
# Loss.item: 3.1505913734436035
# During training one batch, the logits of the output is: tensor([[-2.0188,  5.4823, -3.5423],
#         [-2.2558, -2.5831,  5.0242],
#         [-1.8202,  5.2305, -3.4690],
#         [-2.3924,  5.8413, -3.4418],
#         [ 0.2025,  4.1334, -4.1262],
#         [-2.5089,  5.3649, -2.9889],
#         [-1.5958, -2.9558,  4.8756],
#         [ 3.9602, -3.5802, -0.2084],
#         [-1.2458,  3.2946, -2.5060],
#         [-2.3356,  5.5953, -3.3166]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(1.4679, device='cuda:0')
# Loss.item: 1.4679038524627686
# During training one batch, the logits of the output is: tensor([[-0.1002,  3.9891, -3.9324],
#         [-1.4136,  5.3147, -3.7534],
#         [-1.6994,  5.6272, -3.7638],
#         [-2.4750,  5.7081, -3.2974],
#         [-2.3302,  5.7270, -3.4172],
#         [-1.9032,  5.1261, -3.3425],
#         [-1.9560, -2.8399,  4.9984],
#         [-0.6762, -3.5182,  4.4585],
#         [-2.4717,  5.7359, -3.2435],
#         [-2.3246,  5.7382, -3.4139]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(0.7752, device='cuda:0')
# Loss.item: 0.775191605091095
# During training one batch, the logits of the output is: tensor([[-2.2693,  5.6003, -3.3748],
#         [ 4.9530, -3.2330, -1.7718],
#         [ 4.4781, -2.8408, -2.2278],
#         [ 2.7609, -1.9298, -1.4780],
#         [ 1.1657,  1.6820, -3.1955],
#         [-1.8185,  5.2349, -3.4515],
#         [-2.2561, -2.6011,  5.0325],
#         [-1.5471, -3.0604,  4.8801],
#         [ 3.5408, -2.1011, -2.3382],
#         [-2.3649,  5.8351, -3.4705]], device='cuda:0')
# During training one batch, the loss of the output is: tensor(8.0948, device='cuda:0')
# Loss.item: 8.094846725463867
# During training one batch, the logits of the output is: tensor([[ 2.4773, -4.8830,  2.5578]], device='cuda:0')
# tensor(0.7942)
# tensor(0.7308)
# tensor(0.8576)

# %% [markdown]
# ## Run the training and testing steps

# %%
data = read_airline_data("Tweets_airlines.csv")
split_data(data)
dataset_train, dataset_val, dataset_test = prepare_dataset()
train(dataset_train, dataset_val)
test(model_path = 'second_finetuned_BERT_epoch_5.model')
